# %% [markdown]
# # **Neighborhood Segmentation and Clustering**

# %% [markdown]
# ## Instructions
# ---
#
# In this assignment, you will be required to explore, segment, and cluster the neighborhoods in the city of Toronto. However, unlike New York, the neighborhood data is not readily available on the internet. What is interesting about the field of data science is that each project can be challenging in its unique way, so you need to learn to be agile and refine the skill to learn new libraries and tools quickly depending on the project.
#
# For the Toronto neighborhood data, a Wikipedia page exists that has all the information we need to explore and cluster the neighborhoods in Toronto. You will be required to scrape the Wikipedia page and wrangle the data, clean it, and then read it into a pandas dataframe so that it is in a structured format like the New York dataset.
#
# Once the data is in a structured format, you can replicate the analysis that we did to the New York City dataset to explore and cluster the neighborhoods in the city of Toronto.

# %% [markdown]
# ## Import librairies and print versions
# ---

# %%
import bs4
import requests
import pandas as pd
import numpy as np

print('PANDAS        version: ' + str(pd.__version__))
print('NUMPY         version: ' + str(np.__version__))
print('REQUESTS      version: ' + str(requests.__version__))
print('BEAUTIFULSOUP version: ' + str(bs4.__version__))
# Out:
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# PANDAS        version: 0.23.4
# NUMPY         version: 1.15.0
# REQUESTS      version: 2.18.4
# BEAUTIFULSOUP version: 4.6.0
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ## Scrape Wikipedia Link
# ---
# Assumptions made:
# - Table has 3 columns
# - The first 3 elements inside 'th' are the column names of the table
#     - This is only needed as I'm using the 'find_all' function. If one uses another approach to get the table headers, then this assumption is not needed
# - The next content inside the 'td' after the last line of the table is blank
#     - This is only needed as I'm using the 'find_all' functionality of the 'soup'. If one uses another approach to get table content, for example by looking for "/tbody>""/table>" to find the end of the table, then this assumption is not needed.

# %%
page_link = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
page_response = requests.get(page_link)
page_content = bs4.BeautifulSoup(page_response.content, "html.parser")

# %%
col_names = [col_name.replace('\n', '') for col_name in [c.text for c in page_content.find_all("th")][0:3]] # Column names are inside <th>. There are 3 columns in total
df = pd.DataFrame(columns=col_names)
tbl_content = [c.text for c in page_content.find_all("td")]
for i in range(len(tbl_content)//3):
    if tbl_content[i*3] == '': # hack: the string after last line of the table is blank, thus one can use this to judge the end of the table
        break
    df.loc[len(df)] = [tbl_content[i*3], tbl_content[i*3+1], tbl_content[i*3+2].replace('\n', '')]

# %% [markdown]
# ## Preprocess dataframe
# ---
# In order to create the dataframe:
#
# - The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood
# - Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.
# - More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.
# - If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough. So for the 9th cell in the table on the Wikipedia page, the value of the Borough and the Neighborhood columns will be Queen's Park.
# - Clean your Notebook and add Markdown cells to explain your work and any assumptions you are making.

# %%
# Filter out entries with Borough = Not assigned
df = df[df['Borough']!='Not assigned']

# %%
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough
df_sub_has_neighborhood = df[df['Neighbourhood']!='Not assigned']
df_sub_no_neighborhood = df[df['Neighbourhood']=='Not assigned']
df_sub_no_neighborhood['Neighbourhood'] = df_sub_no_neighborhood['Borough']
df = pd.concat([df_sub_has_neighborhood, df_sub_no_neighborhood])
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Use comma to connect Neighbourhood if there are multiple entries for the same Postcode
df_clean = pd.concat([pd.DataFrame(df.groupby('Postcode')['Borough'].agg('min')), df.groupby('Postcode')['Neighbourhood'].agg(','.join)], axis=1).reset_index(drop=False)

# %%
# Rename the df to be the same as instruction provided
df_clean.rename(columns={'Postcode':'PostalCode', 'Neighbourhood': 'Neighborhood'}, inplace=True)

# Sample visualization 
df_clean.head(10)
# Out:
#   PostalCode      Borough                                   Neighborhood
# 0        M1B  Scarborough                                  Rouge,Malvern
# 1        M1C  Scarborough           Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough                Guildwood,Morningside,West Hill
# 3        M1G  Scarborough                                         Woburn
# 4        M1H  Scarborough                                      Cedarbrae
# 5        M1J  Scarborough                            Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park,Ionview,Kennedy Park
# 7        M1L  Scarborough                  Clairlea,Golden Mile,Oakridge
# 8        M1M  Scarborough  Cliffcrest,Cliffside,Scarborough Village West
# 9        M1N  Scarborough                     Birch Cliff,Cliffside West

# %% [markdown]
# ## Print DataFrame dimensions
# ---
# In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
# Print df shape
df_clean.shape
# Out:
# (103, 3)

# %% [markdown]
# # Part 2
# ---
# Now that you have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, in order to utilize the Foursquare location data, we need to get the latitude and the longitude coordinates of each neighborhood.
#
# This is the csv file that has the geographical coordinates of each postal code: http://cocl.us/Geospatial_data

# %%
# read CSV
lag_lng_df = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
df = df_clean.merge(lag_lng_df, how='inner', left_on='PostalCode', right_on='Postal Code')
df.drop('Postal Code', axis=1, inplace=True)

# %%
df.head(10)
# Out:
#   PostalCode      Borough                                   Neighborhood  \
# 0        M1B  Scarborough                                  Rouge,Malvern
# 1        M1C  Scarborough           Highland Creek,Rouge Hill,Port Union
# 2        M1E  Scarborough                Guildwood,Morningside,West Hill
# 3        M1G  Scarborough                                         Woburn
# 4        M1H  Scarborough                                      Cedarbrae
# 5        M1J  Scarborough                            Scarborough Village
# 6        M1K  Scarborough      East Birchmount Park,Ionview,Kennedy Park
# 7        M1L  Scarborough                  Clairlea,Golden Mile,Oakridge
# 8        M1M  Scarborough  Cliffcrest,Cliffside,Scarborough Village West
# 9        M1N  Scarborough                     Birch Cliff,Cliffside West
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476
# 5  43.744734 -79.239476
# 6  43.727929 -79.262029
# 7  43.711112 -79.284577
# 8  43.716316 -79.239476
# 9  43.692657 -79.264848

# %% [markdown]
# # Part 3
# ---
# Explore and cluster the neighborhoods in Toronto. You can decide to work with only boroughs that contain the word Toronto and then replicate the same analysis we did to the New York City data. It is up to you.
#
# Just make sure:
#
# - to add enough Markdown cells to explain what you decided to do and to report any observations you make.
# - to generate maps to visualize your neighborhoods and how they cluster together.
#
# Once you are happy with your analysis, submit a link to the new Notebook on your Github repository.

# %% [markdown]
# In this part, we will work with only boroughs that contain the word "Toronto", and perform similar analysis as we did to the New York City data

# %% [markdown]
# ## Import libraries

# %%
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
import requests # library to handle requests
# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/jupyterlab/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# ##### Use geopy library to get the latitude and longitude values of Toronto

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of Toronto are 43.653963, -79.387207.

# %%
# Filter dataframe to entries that only contain Toronto
df_toronto = df[df['Borough'].str.contains('Toronto')]

# %% [markdown]
# ##### Create a map of Toronto with neighborhoods plotted.

# %%
# create map of New York using latitude and longitude values
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=12)

# add markers to map
for lat, lng, borough, neighborhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Define Foursquare Credentials and Version

# %%
CLIENT_ID = 'VEZFXJGSG5RCDYPNCTHNALGRCVSCP5RBBAK1X4FL4TK3DG11' # your Foursquare ID
CLIENT_SECRET = '01JSCVYSC42P4XXUQWW5WKVACORF3OBSLR00HR4D1APVB5HT' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: VEZFXJGSG5RCDYPNCTHNALGRCVSCP5RBBAK1X4FL4TK3DG11
# CLIENT_SECRET:01JSCVYSC42P4XXUQWW5WKVACORF3OBSLR00HR4D1APVB5HT

# %% [markdown]
# ##### Explore Neighborhoods

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        
        try:
            # make the GET request
            results = requests.get(url).json()["response"]['groups'][0]['items']

            # return only relevant information for each nearby venue
            venues_list.append([(
                name, 
                lat, 
                lng, 
                v['venue']['name'], 
                v['venue']['location']['lat'], 
                v['venue']['location']['lng'],  
                v['venue']['categories'][0]['name']) for v in results])
        except:
            pass

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=df_toronto['Neighborhood'],
                                   latitudes=df_toronto['Latitude'],
                                   longitudes=df_toronto['Longitude']
                                  )
# Out:
# The Beaches
# The Danforth West,Riverdale
# The Beaches West,India Bazaar
# Studio District
# Lawrence Park
# Davisville North
# North Toronto West
# Davisville
# Moore Park,Summerhill East
# Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West
# Rosedale
# Cabbagetown,St. James Town
# Church and Wellesley
# Harbourfront,Regent Park
# Ryerson,Garden District
# St. James Town
# Berczy Park
# Central Bay Street
# Adelaide,King,Richmond
# Harbourfront East,Toronto Islands,Union Station
# Design Exchange,Toronto Dominion Centre
# Commerce Court,Victoria Hotel
# Roselawn
# Forest Hill North,Forest Hill West
# The Annex,North Midtown,Yorkville
# Harbord,University of Toronto
# Chinatown,Grange Park,Kensington Market
# CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara
# Stn A PO Boxes 25 The Esplanade
# First Canadian Place,Underground city
# Christie
# Dovercourt Village,Dufferin
# Little Portugal,Trinity
# Brockton,Exhibition Place,Parkdale Village
# High Park,The Junction South
# Parkdale,Roncesvalles
# Runnymede,Swansea
# Business reply mail Processing Centre969 Eastern

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 241 uniques categories.

# %% [markdown]
# ## Analyze Each Neighborhood¶

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")

# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 

# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

# grouped
toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

# %% [markdown]
# ##### Let's print each neighborhood along with the top 5 most common venues

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Adelaide,King,Richmond----
#                  venue  freq
# 0          Coffee Shop  0.07
# 1                 Café  0.05
# 2      Thai Restaurant  0.04
# 3           Steakhouse  0.04
# 4  American Restaurant  0.04
#
#
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1        Cocktail Bar  0.05
# 2          Restaurant  0.05
# 3                 Pub  0.04
# 4  Seafood Restaurant  0.04
#
#
# ----Brockton,Exhibition Place,Parkdale Village----
#             venue  freq
# 0     Coffee Shop  0.15
# 1  Breakfast Spot  0.10
# 2            Café  0.10
# 3   Grocery Store  0.05
# 4         Stadium  0.05
#
#
# ----Business reply mail Processing Centre969 Eastern----
#                   venue  freq
# 0    Light Rail Station  0.11
# 1           Pizza Place  0.06
# 2            Restaurant  0.06
# 3               Brewery  0.06
# 4  Fast Food Restaurant  0.06
#
#
# ----CN Tower,Bathurst Quay,Island airport,Harbourfront West,King and Spadina,Railway Lands,South Niagara----
#               venue  freq
# 0    Airport Lounge  0.14
# 1  Airport Terminal  0.14
# 2   Airport Service  0.14
# 3             Plane  0.07
# 4     Boat or Ferry  0.07
#
#
# ----Cabbagetown,St. James Town----
#                venue  freq
# 0        Coffee Shop  0.08
# 1         Restaurant  0.08
# 2        Pizza Place  0.06
# 3                Pub  0.04
# 4  Indian Restaurant  0.04
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.14
# 1                Café  0.06
# 2  Italian Restaurant  0.05
# 3        Burger Joint  0.04
# 4      Ice Cream Shop  0.04
#
#
# ----Chinatown,Grange Park,Kensington Market----
#                            venue  freq
# 0                           Café  0.08
# 1                            Bar  0.07
# 2          Vietnamese Restaurant  0.05
# 3  Vegetarian / Vegan Restaurant  0.05
# 4                         Bakery  0.04
#
#
# ----Christie----
#            venue  freq
# 0           Café  0.19
# 1  Grocery Store  0.19
# 2           Park  0.12
# 3    Coffee Shop  0.06
# 4     Baby Store  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0  Japanese Restaurant  0.07
# 1          Coffee Shop  0.06
# 2     Sushi Restaurant  0.05
# 3         Burger Joint  0.05
# 4              Gay Bar  0.05
#
#
# ----Commerce Court,Victoria Hotel----
#                  venue  freq
# 0          Coffee Shop  0.15
# 1                 Café  0.07
# 2                Hotel  0.06
# 3           Restaurant  0.06
# 4  American Restaurant  0.04
#
#
# ----Davisville----
#               venue  freq
# 0      Dessert Shop  0.08
# 1    Sandwich Place  0.08
# 2  Sushi Restaurant  0.05
# 3       Pizza Place  0.05
# 4              Café  0.05
#
#
# ----Davisville North----
#                venue  freq
# 0               Park  0.14
# 1       Burger Joint  0.14
# 2              Hotel  0.14
# 3  Food & Drink Shop  0.14
# 4     Breakfast Spot  0.14
#
#
# ----Deer Park,Forest Hill SE,Rathnelly,South Hill,Summerhill West----
#               venue  freq
# 0               Pub  0.14
# 1       Coffee Shop  0.14
# 2       Pizza Place  0.07
# 3  Sushi Restaurant  0.07
# 4        Bagel Shop  0.07
#
#
# ----Design Exchange,Toronto Dominion Centre----
#                  venue  freq
# 0          Coffee Shop  0.14
# 1                 Café  0.09
# 2                Hotel  0.08
# 3  American Restaurant  0.04
# 4           Restaurant  0.04
#
#
# ----Dovercourt Village,Dufferin----
#             venue  freq
# 0     Supermarket  0.11
# 1        Pharmacy  0.11
# 2          Bakery  0.11
# 3  Discount Store  0.11
# 4            Pool  0.06
#
#
# ----First Canadian Place,Underground city----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.07
# 2                Hotel  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Forest Hill North,Forest Hill West----
#               venue  freq
# 0  Sushi Restaurant  0.25
# 1     Jewelry Store  0.25
# 2              Park  0.25
# 3             Trail  0.25
# 4       Yoga Studio  0.00
#
#
# ----Harbord,University of Toronto----
#          venue  freq
# 0         Café  0.09
# 1    Bookstore  0.09
# 2  Coffee Shop  0.06
# 3   Restaurant  0.06
# 4       Bakery  0.06
#
#
# ----Harbourfront East,Toronto Islands,Union Station----
#          venue  freq
# 0  Coffee Shop  0.15
# 1        Hotel  0.05
# 2     Aquarium  0.04
# 3         Café  0.04
# 4  Pizza Place  0.04
#
#
# ----Harbourfront,Regent Park----
#          venue  freq
# 0  Coffee Shop  0.18
# 1         Park  0.06
# 2       Bakery  0.06
# 3         Café  0.06
# 4          Pub  0.06
#
#
# ----High Park,The Junction South----
#                 venue  freq
# 0                 Bar  0.08
# 1  Mexican Restaurant  0.08
# 2                Café  0.08
# 3     Thai Restaurant  0.04
# 4           Gastropub  0.04
#
#
# ----Lawrence Park----
#                 venue  freq
# 0            Bus Line   0.2
# 1                Park   0.2
# 2  Dim Sum Restaurant   0.2
# 3         Swim School   0.2
# 4       Jewelry Store   0.2
#
#
# ----Little Portugal,Trinity----
#          venue  freq
# 0          Bar  0.13
# 1         Café  0.06
# 2   Restaurant  0.05
# 3  Coffee Shop  0.05
# 4  Pizza Place  0.03
#
#
# ----Moore Park,Summerhill East----
#                       venue  freq
# 0                Playground  0.33
# 1                      Park  0.33
# 2              Intersection  0.33
# 3   New American Restaurant  0.00
# 4  Mediterranean Restaurant  0.00
#
#
# ----North Toronto West----
#                   venue  freq
# 0        Clothing Store  0.20
# 1   Sporting Goods Shop  0.10
# 2           Coffee Shop  0.10
# 3           Yoga Studio  0.05
# 4  Fast Food Restaurant  0.05
#
#
# ----Parkdale,Roncesvalles----
#                 venue  freq
# 0      Breakfast Spot  0.12
# 1           Gift Shop  0.12
# 2           Piano Bar  0.06
# 3  Italian Restaurant  0.06
# 4       Movie Theater  0.06
#
#
# ----Rosedale----
#          venue  freq
# 0         Park  0.50
# 1        Trail  0.25
# 2   Playground  0.25
# 3  Yoga Studio  0.00
# 4       Museum  0.00
#
#
# ----Roselawn----
#                      venue  freq
# 0  Health & Beauty Service   0.5
# 1                   Garden   0.5
# 2              Yoga Studio   0.0
# 3              Music Venue   0.0
# 4        Martial Arts Dojo   0.0
#
#
# ----Runnymede,Swansea----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1         Pizza Place  0.08
# 2                Café  0.08
# 3    Sushi Restaurant  0.05
# 4  Italian Restaurant  0.05
#
#
# ----Ryerson,Garden District----
#                  venue  freq
# 0       Clothing Store  0.07
# 1          Coffee Shop  0.07
# 2                 Café  0.04
# 3       Cosmetics Shop  0.04
# 4  Japanese Restaurant  0.03
#
#
# ----St. James Town----
#          venue  freq
# 0  Coffee Shop  0.07
# 1   Restaurant  0.06
# 2         Café  0.06
# 3        Hotel  0.04
# 4       Bakery  0.03
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                 venue  freq
# 0         Coffee Shop  0.10
# 1                Café  0.04
# 2          Restaurant  0.04
# 3  Seafood Restaurant  0.03
# 4        Cocktail Bar  0.03
#
#
# ----Studio District----
#                 venue  freq
# 0                Café  0.10
# 1         Coffee Shop  0.08
# 2  Italian Restaurant  0.05
# 3              Bakery  0.05
# 4           Gastropub  0.05
#
#
# ----The Annex,North Midtown,Yorkville----
#             venue  freq
# 0  Sandwich Place  0.11
# 1            Café  0.11
# 2     Coffee Shop  0.11
# 3     Pizza Place  0.07
# 4     Flower Shop  0.04
#
#
# ----The Beaches----
#                      venue  freq
# 0              Coffee Shop  0.25
# 1                      Pub  0.25
# 2                BBQ Joint  0.25
# 3              Yoga Studio  0.00
# 4  New American Restaurant  0.00
#
#
# ----The Beaches West,India Bazaar----
#                   venue  freq
# 0                  Park  0.11
# 1           Pizza Place  0.06
# 2    Italian Restaurant  0.06
# 3  Fast Food Restaurant  0.06
# 4               Brewery  0.06
#
#
# ----The Danforth West,Riverdale----
#                 venue  freq
# 0    Greek Restaurant  0.24
# 1         Coffee Shop  0.07
# 2      Ice Cream Shop  0.07
# 3  Italian Restaurant  0.05
# 4           Bookstore  0.05

# %%
def return_most_common_venues(row, num_top_venues):
    # sort the venues in descending order
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %% [markdown]
# ##### Display the top 10 venues for each neighborhood

# %%
num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted
# Out:
#                                          Neighborhood  \
# 0                              Adelaide,King,Richmond
# 1                                         Berczy Park
# 2          Brockton,Exhibition Place,Parkdale Village
# 3    Business reply mail Processing Centre969 Eastern
# 4   CN Tower,Bathurst Quay,Island airport,Harbourf...
# 5                          Cabbagetown,St. James Town
# 6                                  Central Bay Street
# 7             Chinatown,Grange Park,Kensington Market
# 8                                            Christie
# 9                                Church and Wellesley
# 10                      Commerce Court,Victoria Hotel
# 11                                         Davisville
# 12                                   Davisville North
# 13  Deer Park,Forest Hill SE,Rathnelly,South Hill,...
# 14            Design Exchange,Toronto Dominion Centre
# 15                        Dovercourt Village,Dufferin
# 16              First Canadian Place,Underground city
# 17                 Forest Hill North,Forest Hill West
# 18                      Harbord,University of Toronto
# 19    Harbourfront East,Toronto Islands,Union Station
# 20                           Harbourfront,Regent Park
# 21                       High Park,The Junction South
# 22                                      Lawrence Park
# 23                            Little Portugal,Trinity
# 24                         Moore Park,Summerhill East
# 25                                 North Toronto West
# 26                              Parkdale,Roncesvalles
# 27                                           Rosedale
# 28                                           Roselawn
# 29                                  Runnymede,Swansea
# 30                            Ryerson,Garden District
# 31                                     St. James Town
# 32                    Stn A PO Boxes 25 The Esplanade
# 33                                    Studio District
# 34                  The Annex,North Midtown,Yorkville
# 35                                        The Beaches
# 36                      The Beaches West,India Bazaar
# 37                        The Danforth West,Riverdale
#
#       1st Most Common Venue 2nd Most Common Venue  3rd Most Common Venue  \
# 0               Coffee Shop                  Café             Steakhouse
# 1               Coffee Shop          Cocktail Bar             Restaurant
# 2               Coffee Shop                  Café         Breakfast Spot
# 3        Light Rail Station            Smoke Shop          Auto Workshop
# 4            Airport Lounge       Airport Service       Airport Terminal
# 5               Coffee Shop            Restaurant            Pizza Place
# 6               Coffee Shop                  Café     Italian Restaurant
# 7                      Café                   Bar  Vietnamese Restaurant
# 8                      Café         Grocery Store                   Park
# 9       Japanese Restaurant           Coffee Shop                Gay Bar
# 10              Coffee Shop                  Café                  Hotel
# 11           Sandwich Place          Dessert Shop       Sushi Restaurant
# 12             Burger Joint        Breakfast Spot         Sandwich Place
# 13              Coffee Shop                   Pub     Light Rail Station
# 14              Coffee Shop                  Café                  Hotel
# 15                 Pharmacy        Discount Store                 Bakery
# 16              Coffee Shop                  Café                  Hotel
# 17                    Trail      Sushi Restaurant                   Park
# 18                Bookstore                  Café                    Bar
# 19              Coffee Shop                 Hotel               Aquarium
# 20              Coffee Shop                  Café                 Bakery
# 21                      Bar    Mexican Restaurant                   Café
# 22                 Bus Line                  Park          Jewelry Store
# 23                      Bar                  Café            Coffee Shop
# 24             Intersection            Playground                   Park
# 25           Clothing Store   Sporting Goods Shop            Coffee Shop
# 26           Breakfast Spot             Gift Shop              Piano Bar
# 27                     Park            Playground                  Trail
# 28  Health & Beauty Service                Garden             Comic Shop
# 29              Coffee Shop                  Café            Pizza Place
# 30           Clothing Store           Coffee Shop         Cosmetics Shop
# 31              Coffee Shop            Restaurant                   Café
# 32              Coffee Shop            Restaurant                   Café
# 33                     Café           Coffee Shop                 Bakery
# 34           Sandwich Place           Coffee Shop                   Café
# 35              Coffee Shop                   Pub              BBQ Joint
# 36                     Park        Ice Cream Shop            Pizza Place
# 37         Greek Restaurant        Ice Cream Shop            Coffee Shop
#
#             4th Most Common Venue      5th Most Common Venue  \
# 0             American Restaurant            Thai Restaurant
# 1                      Steakhouse                Cheese Shop
# 2                   Grocery Store         Italian Restaurant
# 3                      Comic Shop                Pizza Place
# 4                   Boat or Ferry           Sculpture Garden
# 5                            Café          Indian Restaurant
# 6                  Sandwich Place                        Bar
# 7   Vegetarian / Vegan Restaurant                Coffee Shop
# 8                       Nightclub                 Baby Store
# 9                    Burger Joint           Sushi Restaurant
# 10                     Restaurant        American Restaurant
# 11                    Pizza Place                       Café
# 12                           Park             Clothing Store
# 13                     Sports Bar      Vietnamese Restaurant
# 14                     Restaurant        American Restaurant
# 15                    Supermarket                       Bank
# 16                     Restaurant                 Steakhouse
# 17                  Jewelry Store              Women's Store
# 18                         Bakery        Japanese Restaurant
# 19                    Pizza Place                       Café
# 20                           Park                        Pub
# 21                          Diner                  Irish Pub
# 22                    Swim School         Dim Sum Restaurant
# 23                     Restaurant    New American Restaurant
# 24               Doner Restaurant               Dessert Shop
# 25        Health & Beauty Service         Chinese Restaurant
# 26                   Dessert Shop                  Bookstore
# 27                  Women's Store                 Donut Shop
# 28                   Concert Hall         Falafel Restaurant
# 29             Italian Restaurant           Sushi Restaurant
# 30                           Café  Middle Eastern Restaurant
# 31                          Hotel               Cocktail Bar
# 32             Seafood Restaurant                      Hotel
# 33                      Gastropub        American Restaurant
# 34                    Pizza Place                   Pharmacy
# 35                  Women's Store         Dim Sum Restaurant
# 36                  Movie Theater                        Pub
# 37                      Bookstore         Italian Restaurant
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0                Clothing Store                   Gym                 Hotel
# 1                          Café                   Pub        Farmers Market
# 2         Performing Arts Venue             Pet Store                   Gym
# 3                       Butcher      Recording Studio         Burrito Place
# 4                       Airport    Airport Food Court          Airport Gate
# 5            Italian Restaurant    Chinese Restaurant                Bakery
# 6                  Burger Joint        Ice Cream Shop   Japanese Restaurant
# 7            Chinese Restaurant    Mexican Restaurant                Bakery
# 8                         Diner    Athletics & Sports    Italian Restaurant
# 9                    Restaurant                   Pub             Nightclub
# 10                    Gastropub         Deli / Bodega            Steakhouse
# 11              Thai Restaurant    Italian Restaurant           Coffee Shop
# 12            Food & Drink Shop                 Hotel        Discount Store
# 13            Convenience Store           Pizza Place           Supermarket
# 14           Italian Restaurant             Gastropub            Sports Bar
# 15                         Café          Liquor Store                  Pool
# 16          American Restaurant    Seafood Restaurant             Gastropub
# 17                        Diner        Discount Store               Dog Run
# 18                  Coffee Shop            Restaurant              Beer Bar
# 19                      Brewery    Italian Restaurant        Scenic Lookout
# 20               Breakfast Spot    Mexican Restaurant               Theater
# 21          Arts & Crafts Store           Flea Market   Fried Chicken Joint
# 22                 Dessert Shop           Event Space  Ethiopian Restaurant
# 23                 Cocktail Bar      Asian Restaurant           Pizza Place
# 24           Dim Sum Restaurant                 Diner        Discount Store
# 25                 Dessert Shop                 Diner  Fast Food Restaurant
# 26  Eastern European Restaurant                   Bar          Burger Joint
# 27           Dim Sum Restaurant                 Diner        Discount Store
# 28                  Event Space  Ethiopian Restaurant     Electronics Store
# 29           Falafel Restaurant     French Restaurant     Fish & Chips Shop
# 30          Japanese Restaurant            Restaurant      Ramen Restaurant
# 31               Cosmetics Shop                Bakery        Clothing Store
# 32                          Pub          Cocktail Bar                   Gym
# 33           Italian Restaurant                  Bank                   Bar
# 34            French Restaurant          Liquor Store          Burger Joint
# 35           Falafel Restaurant           Event Space  Ethiopian Restaurant
# 36                Burrito Place          Burger Joint        Sandwich Place
# 37               Cosmetics Shop               Brewery       Bubble Tea Shop
#
#           9th Most Common Venue       10th Most Common Venue
# 0                Breakfast Spot                          Bar
# 1                        Bakery           Seafood Restaurant
# 2                  Climbing Gym         Caribbean Restaurant
# 3                    Restaurant                      Brewery
# 4                      Boutique              Harbor / Marina
# 5                           Pub                 Liquor Store
# 6     Middle Eastern Restaurant                  Salad Place
# 7           Dumpling Restaurant                 Dessert Shop
# 8                    Restaurant            Convenience Store
# 9                   Men's Store     Mediterranean Restaurant
# 10           Seafood Restaurant                          Gym
# 11                   Restaurant           Seafood Restaurant
# 12                      Dog Run             Doner Restaurant
# 13             Sushi Restaurant          Fried Chicken Joint
# 14                Deli / Bodega                          Gym
# 15                  Music Venue                          Bar
# 16                Deli / Bodega                 Concert Hall
# 17             Doner Restaurant                   Donut Shop
# 18                          Pub           Italian Restaurant
# 19                   Sports Bar               History Museum
# 20                 Dessert Shop               Chocolate Shop
# 21       Furniture / Home Store                 Antique Shop
# 22            Electronics Store  Eastern European Restaurant
# 23                  Men's Store        Vietnamese Restaurant
# 24                      Dog Run                Women's Store
# 25           Mexican Restaurant                         Park
# 26                      Dog Run           Italian Restaurant
# 27                      Dog Run             Doner Restaurant
# 28  Eastern European Restaurant          Dumpling Restaurant
# 29                   Baby Store                          Pub
# 30                  Pizza Place              Bubble Tea Shop
# 31                         Park                    Gastropub
# 32                     Beer Bar                     Creperie
# 33                  Fish Market                    Juice Bar
# 34            Jewish Restaurant                  Flower Shop
# 35            Electronics Store  Eastern European Restaurant
# 36                      Brewery                 Liquor Store
# 37                   Restaurant                         Café

# %% [markdown]
# ##### Cluster Neighborhoods

# %%
# set number of clusters
kclusters = 6

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# %%
toronto_merged = df_toronto

# add clustering labels
toronto_merged['Cluster Labels'] = kmeans.labels_

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')

toronto_merged.head() # check the last columns!
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
#    PostalCode          Borough                   Neighborhood   Latitude  \
# 37        M4E     East Toronto                    The Beaches  43.676357
# 41        M4K     East Toronto    The Danforth West,Riverdale  43.679557
# 42        M4L     East Toronto  The Beaches West,India Bazaar  43.668999
# 43        M4M     East Toronto                Studio District  43.659526
# 44        M4N  Central Toronto                  Lawrence Park  43.728020
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 37 -79.293031               1           Coffee Shop                   Pub
# 41 -79.352188               1      Greek Restaurant        Ice Cream Shop
# 42 -79.315572               1                  Park        Ice Cream Shop
# 43 -79.340923               1                  Café           Coffee Shop
# 44 -79.388790               1              Bus Line                  Park
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 37             BBQ Joint         Women's Store    Dim Sum Restaurant
# 41           Coffee Shop             Bookstore    Italian Restaurant
# 42           Pizza Place         Movie Theater                   Pub
# 43                Bakery             Gastropub   American Restaurant
# 44         Jewelry Store           Swim School    Dim Sum Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 37    Falafel Restaurant           Event Space  Ethiopian Restaurant
# 41        Cosmetics Shop               Brewery       Bubble Tea Shop
# 42         Burrito Place          Burger Joint        Sandwich Place
# 43    Italian Restaurant                  Bank                   Bar
# 44          Dessert Shop           Event Space  Ethiopian Restaurant
#
#    9th Most Common Venue       10th Most Common Venue
# 37     Electronics Store  Eastern European Restaurant
# 41            Restaurant                         Café
# 42               Brewery                 Liquor Store
# 43           Fish Market                    Juice Bar
# 44     Electronics Store  Eastern European Restaurant

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i+x+(i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ##### Examine Clusters

# %% [markdown]
# Cluster 1

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, :]
# Out:
#    PostalCode           Borough              Neighborhood  Latitude  \
# 53        M5A  Downtown Toronto  Harbourfront,Regent Park  43.65426
# 83        M6R      West Toronto     Parkdale,Roncesvalles  43.64896
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 53 -79.360636               0           Coffee Shop                  Café
# 83 -79.456325               0        Breakfast Spot             Gift Shop
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 53                Bakery                  Park                   Pub
# 83             Piano Bar          Dessert Shop             Bookstore
#
#           6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 53               Breakfast Spot    Mexican Restaurant               Theater
# 83  Eastern European Restaurant                   Bar          Burger Joint
#
#    9th Most Common Venue 10th Most Common Venue
# 53          Dessert Shop         Chocolate Shop
# 83               Dog Run     Italian Restaurant

# %% [markdown]
# Cluster 2

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, :]
# Out:
#    PostalCode           Borough  \
# 37        M4E      East Toronto
# 41        M4K      East Toronto
# 42        M4L      East Toronto
# 43        M4M      East Toronto
# 44        M4N   Central Toronto
# 45        M4P   Central Toronto
# 46        M4R   Central Toronto
# 47        M4S   Central Toronto
# 48        M4T   Central Toronto
# 49        M4V   Central Toronto
# 50        M4W  Downtown Toronto
# 51        M4X  Downtown Toronto
# 52        M4Y  Downtown Toronto
# 54        M5B  Downtown Toronto
# 55        M5C  Downtown Toronto
# 56        M5E  Downtown Toronto
# 58        M5H  Downtown Toronto
# 59        M5J  Downtown Toronto
# 60        M5K  Downtown Toronto
# 61        M5L  Downtown Toronto
# 64        M5P   Central Toronto
# 66        M5S  Downtown Toronto
# 67        M5T  Downtown Toronto
# 70        M5X  Downtown Toronto
# 75        M6G  Downtown Toronto
# 76        M6H      West Toronto
# 77        M6J      West Toronto
# 78        M6K      West Toronto
# 82        M6P      West Toronto
# 84        M6S      West Toronto
# 87        M7Y      East Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 37                                        The Beaches  43.676357 -79.293031
# 41                        The Danforth West,Riverdale  43.679557 -79.352188
# 42                      The Beaches West,India Bazaar  43.668999 -79.315572
# 43                                    Studio District  43.659526 -79.340923
# 44                                      Lawrence Park  43.728020 -79.388790
# 45                                   Davisville North  43.712751 -79.390197
# 46                                 North Toronto West  43.715383 -79.405678
# 47                                         Davisville  43.704324 -79.388790
# 48                         Moore Park,Summerhill East  43.689574 -79.383160
# 49  Deer Park,Forest Hill SE,Rathnelly,South Hill,...  43.686412 -79.400049
# 50                                           Rosedale  43.679563 -79.377529
# 51                         Cabbagetown,St. James Town  43.667967 -79.367675
# 52                               Church and Wellesley  43.665860 -79.383160
# 54                            Ryerson,Garden District  43.657162 -79.378937
# 55                                     St. James Town  43.651494 -79.375418
# 56                                        Berczy Park  43.644771 -79.373306
# 58                             Adelaide,King,Richmond  43.650571 -79.384568
# 59    Harbourfront East,Toronto Islands,Union Station  43.640816 -79.381752
# 60            Design Exchange,Toronto Dominion Centre  43.647177 -79.381576
# 61                      Commerce Court,Victoria Hotel  43.648198 -79.379817
# 64                 Forest Hill North,Forest Hill West  43.696948 -79.411307
# 66                      Harbord,University of Toronto  43.662696 -79.400049
# 67            Chinatown,Grange Park,Kensington Market  43.653206 -79.400049
# 70              First Canadian Place,Underground city  43.648429 -79.382280
# 75                                           Christie  43.669542 -79.422564
# 76                        Dovercourt Village,Dufferin  43.669005 -79.442259
# 77                            Little Portugal,Trinity  43.647927 -79.419750
# 78         Brockton,Exhibition Place,Parkdale Village  43.636847 -79.428191
# 82                       High Park,The Junction South  43.661608 -79.464763
# 84                                  Runnymede,Swansea  43.651571 -79.484450
# 87   Business reply mail Processing Centre969 Eastern  43.662744 -79.321558
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 37               1           Coffee Shop                   Pub
# 41               1      Greek Restaurant        Ice Cream Shop
# 42               1                  Park        Ice Cream Shop
# 43               1                  Café           Coffee Shop
# 44               1              Bus Line                  Park
# 45               1          Burger Joint        Breakfast Spot
# 46               1        Clothing Store   Sporting Goods Shop
# 47               1        Sandwich Place          Dessert Shop
# 48               1          Intersection            Playground
# 49               1           Coffee Shop                   Pub
# 50               1                  Park            Playground
# 51               1           Coffee Shop            Restaurant
# 52               1   Japanese Restaurant           Coffee Shop
# 54               1        Clothing Store           Coffee Shop
# 55               1           Coffee Shop            Restaurant
# 56               1           Coffee Shop          Cocktail Bar
# 58               1           Coffee Shop                  Café
# 59               1           Coffee Shop                 Hotel
# 60               1           Coffee Shop                  Café
# 61               1           Coffee Shop                  Café
# 64               1                 Trail      Sushi Restaurant
# 66               1             Bookstore                  Café
# 67               1                  Café                   Bar
# 70               1           Coffee Shop                  Café
# 75               1                  Café         Grocery Store
# 76               1              Pharmacy        Discount Store
# 77               1                   Bar                  Café
# 78               1           Coffee Shop                  Café
# 82               1                   Bar    Mexican Restaurant
# 84               1           Coffee Shop                  Café
# 87               1    Light Rail Station            Smoke Shop
#
#     3rd Most Common Venue          4th Most Common Venue  \
# 37              BBQ Joint                  Women's Store
# 41            Coffee Shop                      Bookstore
# 42            Pizza Place                  Movie Theater
# 43                 Bakery                      Gastropub
# 44          Jewelry Store                    Swim School
# 45         Sandwich Place                           Park
# 46            Coffee Shop        Health & Beauty Service
# 47       Sushi Restaurant                    Pizza Place
# 48                   Park               Doner Restaurant
# 49     Light Rail Station                     Sports Bar
# 50                  Trail                  Women's Store
# 51            Pizza Place                           Café
# 52                Gay Bar                   Burger Joint
# 54         Cosmetics Shop                           Café
# 55                   Café                          Hotel
# 56             Restaurant                     Steakhouse
# 58             Steakhouse            American Restaurant
# 59               Aquarium                    Pizza Place
# 60                  Hotel                     Restaurant
# 61                  Hotel                     Restaurant
# 64                   Park                  Jewelry Store
# 66                    Bar                         Bakery
# 67  Vietnamese Restaurant  Vegetarian / Vegan Restaurant
# 70                  Hotel                     Restaurant
# 75                   Park                      Nightclub
# 76                 Bakery                    Supermarket
# 77            Coffee Shop                     Restaurant
# 78         Breakfast Spot                  Grocery Store
# 82                   Café                          Diner
# 84            Pizza Place             Italian Restaurant
# 87          Auto Workshop                     Comic Shop
#
#         5th Most Common Venue  6th Most Common Venue 7th Most Common Venue  \
# 37         Dim Sum Restaurant     Falafel Restaurant           Event Space
# 41         Italian Restaurant         Cosmetics Shop               Brewery
# 42                        Pub          Burrito Place          Burger Joint
# 43        American Restaurant     Italian Restaurant                  Bank
# 44         Dim Sum Restaurant           Dessert Shop           Event Space
# 45             Clothing Store      Food & Drink Shop                 Hotel
# 46         Chinese Restaurant           Dessert Shop                 Diner
# 47                       Café        Thai Restaurant    Italian Restaurant
# 48               Dessert Shop     Dim Sum Restaurant                 Diner
# 49      Vietnamese Restaurant      Convenience Store           Pizza Place
# 50                 Donut Shop     Dim Sum Restaurant                 Diner
# 51          Indian Restaurant     Italian Restaurant    Chinese Restaurant
# 52           Sushi Restaurant             Restaurant                   Pub
# 54  Middle Eastern Restaurant    Japanese Restaurant            Restaurant
# 55               Cocktail Bar         Cosmetics Shop                Bakery
# 56                Cheese Shop                   Café                   Pub
# 58            Thai Restaurant         Clothing Store                   Gym
# 59                       Café                Brewery    Italian Restaurant
# 60        American Restaurant     Italian Restaurant             Gastropub
# 61        American Restaurant              Gastropub         Deli / Bodega
# 64              Women's Store                  Diner        Discount Store
# 66        Japanese Restaurant            Coffee Shop            Restaurant
# 67                Coffee Shop     Chinese Restaurant    Mexican Restaurant
# 70                 Steakhouse    American Restaurant    Seafood Restaurant
# 75                 Baby Store                  Diner    Athletics & Sports
# 76                       Bank                   Café          Liquor Store
# 77    New American Restaurant           Cocktail Bar      Asian Restaurant
# 78         Italian Restaurant  Performing Arts Venue             Pet Store
# 82                  Irish Pub    Arts & Crafts Store           Flea Market
# 84           Sushi Restaurant     Falafel Restaurant     French Restaurant
# 87                Pizza Place                Butcher      Recording Studio
#
#    8th Most Common Venue   9th Most Common Venue       10th Most Common Venue
# 37  Ethiopian Restaurant       Electronics Store  Eastern European Restaurant
# 41       Bubble Tea Shop              Restaurant                         Café
# 42        Sandwich Place                 Brewery                 Liquor Store
# 43                   Bar             Fish Market                    Juice Bar
# 44  Ethiopian Restaurant       Electronics Store  Eastern European Restaurant
# 45        Discount Store                 Dog Run             Doner Restaurant
# 46  Fast Food Restaurant      Mexican Restaurant                         Park
# 47           Coffee Shop              Restaurant           Seafood Restaurant
# 48        Discount Store                 Dog Run                Women's Store
# 49           Supermarket        Sushi Restaurant          Fried Chicken Joint
# 50        Discount Store                 Dog Run             Doner Restaurant
# 51                Bakery                     Pub                 Liquor Store
# 52             Nightclub             Men's Store     Mediterranean Restaurant
# 54      Ramen Restaurant             Pizza Place              Bubble Tea Shop
# 55        Clothing Store                    Park                    Gastropub
# 56        Farmers Market                  Bakery           Seafood Restaurant
# 58                 Hotel          Breakfast Spot                          Bar
# 59        Scenic Lookout              Sports Bar               History Museum
# 60            Sports Bar           Deli / Bodega                          Gym
# 61            Steakhouse      Seafood Restaurant                          Gym
# 64               Dog Run        Doner Restaurant                   Donut Shop
# 66              Beer Bar                     Pub           Italian Restaurant
# 67                Bakery     Dumpling Restaurant                 Dessert Shop
# 70             Gastropub           Deli / Bodega                 Concert Hall
# 75    Italian Restaurant              Restaurant            Convenience Store
# 76                  Pool             Music Venue                          Bar
# 77           Pizza Place             Men's Store        Vietnamese Restaurant
# 78                   Gym            Climbing Gym         Caribbean Restaurant
# 82   Fried Chicken Joint  Furniture / Home Store                 Antique Shop
# 84     Fish & Chips Shop              Baby Store                          Pub
# 87         Burrito Place              Restaurant                      Brewery

# %% [markdown]
# Cluster 3

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, :]
# Out:
#    PostalCode           Borough        Neighborhood   Latitude  Longitude  \
# 57        M5G  Downtown Toronto  Central Bay Street  43.657952 -79.387383
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 57               2           Coffee Shop                  Café
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 57    Italian Restaurant        Sandwich Place                   Bar
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 57          Burger Joint        Ice Cream Shop   Japanese Restaurant
#
#         9th Most Common Venue 10th Most Common Venue
# 57  Middle Eastern Restaurant            Salad Place

# %% [markdown]
# Cluster 4

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, :]
# Out:
#    PostalCode           Borough  \
# 65        M5R   Central Toronto
# 68        M5V  Downtown Toronto
#
#                                          Neighborhood   Latitude  Longitude  \
# 65                  The Annex,North Midtown,Yorkville  43.672710 -79.405678
# 68  CN Tower,Bathurst Quay,Island airport,Harbourf...  43.628947 -79.394420
#
#     Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 65               3        Sandwich Place           Coffee Shop
# 68               3        Airport Lounge       Airport Service
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 65                  Café           Pizza Place              Pharmacy
# 68      Airport Terminal         Boat or Ferry      Sculpture Garden
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 65     French Restaurant          Liquor Store          Burger Joint
# 68               Airport    Airport Food Court          Airport Gate
#
#    9th Most Common Venue 10th Most Common Venue
# 65     Jewish Restaurant            Flower Shop
# 68              Boutique        Harbor / Marina

# %% [markdown]
# Cluster 5

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, :]
# Out:
#    PostalCode          Borough Neighborhood   Latitude  Longitude  \
# 63        M5N  Central Toronto     Roselawn  43.711695 -79.416936
#
#     Cluster Labels    1st Most Common Venue 2nd Most Common Venue  \
# 63               4  Health & Beauty Service                Garden
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 63            Comic Shop          Concert Hall    Falafel Restaurant
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 63           Event Space  Ethiopian Restaurant     Electronics Store
#
#           9th Most Common Venue 10th Most Common Venue
# 63  Eastern European Restaurant    Dumpling Restaurant

# %% [markdown]
# Cluster 6

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 5, :]
# Out:
#    PostalCode           Borough                     Neighborhood   Latitude  \
# 69        M5W  Downtown Toronto  Stn A PO Boxes 25 The Esplanade  43.646435
#
#     Longitude  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 69 -79.374846               5           Coffee Shop            Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 69                  Café    Seafood Restaurant                 Hotel
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 69                   Pub          Cocktail Bar                   Gym
#
#    9th Most Common Venue 10th Most Common Venue
# 69              Beer Bar               Creperie
